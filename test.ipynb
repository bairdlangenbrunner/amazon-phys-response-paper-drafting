# %%
! rm gp2_moisture_budget_calculations-Copy1.ipynb

# %%
# !mkdir old

# %%
import numpy

import matplotlib.pyplot as mp

# %matplotlib inline

# %%
rand_array = numpy.random.rand(1000,1000)

# %%
mp.imshow(rand_array)
